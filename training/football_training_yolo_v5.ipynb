# %%
dataset_path = 'D:/OneDrive/Documents/code/Football_Analysis_System/DFL---Bundesliga-Data-Shootout/training/football-players-detection-1/football-players-detection-1'  # Update this path

# !yolo task=detect mode=train model=yolov5mu.pt data={dataset_path}/data.yaml epochs=100 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.3.7 available 😃 Update with 'pip install -U ultralytics'
# train: Scanning D:\OneDrive\Documents\code\DFL--Bundesliga-Data-Shootout\training\football-players-detection-1\football-players-detection-1\train\labels...:   0%|          | 0/250 [00:00<?, ?it/s]
# train: Scanning D:\OneDrive\Documents\code\DFL--Bundesliga-Data-Shootout\training\football-players-detection-1\football-players-detection-1\train\labels... 77 images, 0 backgrounds, 0 corrupt:  31%|███       | 77/250 [00:00<00:00, 759.24it/s]
# train: Scanning D:\OneDrive\Documents\code\DFL--Bundesliga-Data-Shootout\training\football-players-detection-1\football-players-detection-1\train\labels... 244 images, 0 backgrounds, 0 corrupt:  98%|█████████▊| 244/250 [00:00<00:00, 1263.87it/s]
# ...
